# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/Correlation Animations - Sheet1.csv")

# %%
df.head()
# Out:
#   Code      Region Population 2022 share kids    pib  theaters  \
# 0   SP  South East      44,411,238      6.40%  2,148       226
# 1   RJ  South East      16,054,524      6.30%  1,971        87
# 2   MG  South East      20,538,718      5.90%  1,529        77
# 3   PR       South      11,444,380      6.60%  1,846        58
# 4   RS       South      10,882,965      6.00%  2,087        51
#
#           desc state CDI Animations BDI Animations
# 0          São Paulo           154%           164%
# 1     Rio de Janeiro           144%           148%
# 2       Minas Gerais            71%            68%
# 3             Paraná           118%           108%
# 4  Rio Grande do Sul            89%            84%

# %%
df.dtypes
# Out:
# Code               object
# Region             object
# Population 2022    object
# share kids         object
# pib                object
# theaters            int64
# desc state         object
# CDI Animations     object
# BDI Animations     object
# dtype: object

# %%
df['Population 2022'] = df['Population 2022'].str.replace(',', '')

# %%
df['pib'] = df['pib'].str.replace(',', '')

# %%
df['CDI Animations'] = df['CDI Animations'].str.replace('%', '')
df['BDI Animations'] = df['BDI Animations'].str.replace('%', '')

# %%
df.head()
# Out:
#   Code      Region Population 2022 share kids   pib  theaters  \
# 0   SP  South East        44411238      6.40%  2148       226
# 1   RJ  South East        16054524      6.30%  1971        87
# 2   MG  South East        20538718      5.90%  1529        77
# 3   PR       South        11444380      6.60%  1846        58
# 4   RS       South        10882965      6.00%  2087        51
#
#           desc state CDI Animations BDI Animations
# 0          São Paulo            154            164
# 1     Rio de Janeiro            144            148
# 2       Minas Gerais             71             68
# 3             Paraná            118            108
# 4  Rio Grande do Sul             89             84
